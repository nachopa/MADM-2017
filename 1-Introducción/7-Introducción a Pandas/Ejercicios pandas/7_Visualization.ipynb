# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
# It is recomended also to use **seaborn** library
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sb
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from titanic.csv

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic = pd.read_csv('data/titanic.csv')

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %% [markdown]
# ### Step 5. Create a pairplot to check how variables correlate

# %%
sb.pairplot(titanic.dropna())
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
males = titanic[titanic.Sex == 'male']
females = titanic[titanic.Sex == 'female']

plt.scatter(females.Age, females.Fare, c="red", alpha=0.3, label='Females')
plt.scatter(males.Age, males.Fare, c="blue", alpha=0.3, label='Males')

plt.legend()
plt.show()

# %% [markdown]
# ### Step 7. How many people survived?

# %%
titanic.Survived.sum()
# Out:
# 342

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
pd.DataFrame.hist(titanic,column="Fare payed")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fda21517780>]], dtype=object)

# %% [markdown]
# ### Step 9: Create a diagonal correlation plot af all variables ([tip](http://seaborn.pydata.org/examples/many_pairwise_correlations.html))

# %%
# Compute the correlation matrix
corr = titanic.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Draw the heatmap with the mask and correct aspect ratio
sb.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
